# %%
1) Guido Van Rossum

2) Python is an interpreted programming language, supporting object- oriented, structured, and functional programming.

3) Yes, Python is a case- sensitive language

4).py

5) Python is an interpreted language.

6) There are many types of code blocks such as 
    a) Function : It performs a specific task.
    b) Class : It is blue print of creating object.
    c) Conditional Statement : It is a block of code which execute only when certaing condition is met.
    d) Loop: It is a block of codes that repeat certain number of times or until its condition is met.
    etc.
    
7) # character

8) There are several functions:
    a) sys.version - This function returns a string containing the version number of the python interpreter.
    b) platform.python_version() - This function returns a string containing the version number of the python interpreter with some additional information.
    c) platform.python_implemention() - These function return a string containing the  name of the python implementation (eg - "CPython", "Jython" , etc).
    These functions are available in python3.x and will not work on older version.

9) lambda

10) Preferred installer program.

11) print() function
    input() function
    append()function
    insert() function
    extend() fuction 
    type () function
    dir() fuction

12) An identifier can have a maximum length of 79 characters in Python.

13) Benifits of Python :
    a) Become Data Science.
    b) Scientific and Mathematical computing.
    c) web development.
    d) Basic Game Devlopment.
    e) Security and penetration testing.
    
14) Python uses a portion of the memory for internal use and non-object memory.

15) Python installation on window :
    a) Go to www.python.org/downloads/
    b) Download python os as per your system requirement 
    c) click on python released for windows, select the link for latest python 3.
    d) Scroll to the bottom select eigther window X86 -64 executable installer for 64-bit or windows X86 executable installer for 32 bit.

    
16) Indentation refers to the spaces at the beginning of a code line. Where in other programming languages the indentation in code os for readability only, the identation in Python is very important. Python uses indentation to indicate a block of a code.
